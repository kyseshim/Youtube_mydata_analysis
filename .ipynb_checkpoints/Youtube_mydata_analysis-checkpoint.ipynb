# %%
#!pip install --upgrade google-api-python-client
#!pip install oauth2client

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import apikey

import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
warnings.filterwarnings('ignore')

# %%
dev_key = apikey.api_key
api_service_name = "youtube"
api_ver = "v3"

# %%
youtube = build(api_service_name, api_ver, developerKey = dev_key)

# %%
search_response = youtube.search().list(
    q = "공부하는섭이",
    order = "relevance",
    part = "snippet",
    maxResults = 50
    ).execute()

# %%
channel_id = search_response['items'][0]['id']['channelId']

# %%
playlists = youtube.playlists().list(
    channelId = channel_id,
    part = "snippet",
    maxResults = 20
    ).execute()

# %%
import pandas as pd

ids=[]
titles=[]
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])
    
df=pd.DataFrame([ids,titles]).T
df.columns=['PlayLists','Titles']

df.head(5)
# Out:
#                             PlayLists       Titles
# 0  PLfkfgvn_kFAU6nfQ-zL_JV8D_SWeHVuRV       Shorts
# 1  PLfkfgvn_kFAX8jvsuRcoFp6CFPAUehok8      일상 Vlog
# 2  PLfkfgvn_kFAV4YksRjqGU_H9dWmMRylSG  Q&A / 정보 제공

# %%
#Videos' list
dtcu=df['PlayLists'][0]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu,
    part='snippet',
    maxResults=50)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf=pd.DataFrame([date,video_names,video_ids]).T
vdf.columns=['Date','Title','IDS']
vdf['ListNo'] = 1
vdf
# Out:
#                    Date                                            Title  \
# 0  2022-08-20T20:27:40Z                  한국 음식이 너무 그리운(?) 미국 유학생 #shorts
# 1  2022-08-20T20:27:40Z                            미국에서 보내는 첫 생일 #Shorts
# 2  2022-08-20T20:27:40Z                            맛이 가버린 텍사스 날씨 #shorts
# 3  2022-08-20T20:27:40Z                     새해를 맞이하는 게으른 유학생의 자세 #Shorts
# 4  2022-08-20T20:27:40Z     #Shorts Merry Christmas! 미국 유학생이 크리스마스 즐기는 법
# 5  2022-08-20T20:27:40Z  IPhone 13 Pro 예구 - 컴퓨터, 아이패드 다음은 아이폰이에요 #shorts
# 6  2022-08-20T20:27:40Z            이것이 미국의 스케일.. This is America #shorts
# 7  2022-08-20T20:28:50Z                    낮에 영상 20도인데 밤에 눈이 온다? #shorts
#
#            IDS  ListNo
# 0  EQ4xjclxig0       1
# 1  AA2ls2fBwdU       1
# 2  o12WipNjpwM       1
# 3  RqM5xtkC5HM       1
# 4  uTeI3PZPAD0       1
# 5  Kfzax_mz-lA       1
# 6  yXLNw6gebsA       1
# 7  7mzOuRN1zq0       1

# %%
dtcu2=df['PlayLists'][1]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu2,
    part='snippet',
    maxResults=50)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf2=pd.DataFrame([date,video_names,video_ids]).T
vdf2.columns=['Date','Title','IDS']
vdf2['ListNo'] = 2
vdf2
# Out:
#                     Date                                              Title  \
# 0   2022-08-20T20:26:52Z                      미국 대학원생 여름학기 일상 Vlog - 벌써 1년?
# 1   2022-08-20T20:26:52Z         미국 인턴 구르는 Vlog - 본격 예비 외노자(되고싶다)의 미국 회사 체험
# 2   2022-08-20T20:26:52Z        여름방학 맞아 푹 삶아진(?) 미국 대학원생 Vlog - 응 몰라 일단 쉴거야
# 3   2022-08-20T20:26:52Z  기말고사까지 우당탕탕 치른 미국 대학원생 Vlog - 이겨내는 것이 아니라 버티는 것이다
# 4   2022-08-20T20:26:52Z          또 첫 학기 어찌저찌 보낸 미국 대학원생 Vlog - 달라지기 위한 나날들
# 5   2022-08-20T20:26:52Z      미국 대학원생 방학에 좀 숨 돌리는 Vlog - 아니 왜 벌써 개강인데.....?
# 6   2022-08-20T20:26:52Z          미국 대학원생 연말 홀로 즐기는 Vlog - 혼자서도 연말 잘 보내는 방법
# 7   2022-08-20T20:26:52Z                   해커톤 해도 됩니까? - 미국 대학원생 첫 해커톤 Vlog
# 8   2022-08-20T20:26:52Z                    미국 대학원생 첫학기 드디어 끝난 Vlog - 해방이니?
# 9   2022-08-20T20:26:52Z                  미국 대학원생 중간고사 끝난 Vlog - 도랏나 왜 똑같은데
# 10  2022-08-20T20:26:52Z        미국 대학원생 중간고사 Vlog - 할로윈도 못 쉬게 하는 교수님은 풍각쟁이야
# 11  2022-08-20T20:26:52Z              미국 대학원생 일상 Vlog -  나 자신을 지켜내기 위한 고군분투
# 12  2022-08-20T20:26:52Z             미국 데이터 대학원생 일상 Vlog - 공부는 안하고 폰을 사부렀어?
# 13  2022-08-20T20:26:52Z            미국 데이터 대학원생 일상 Vlog - 배우고 싶은데 머리에 안 들어옴
# 14  2022-08-20T20:26:52Z                   공부만 하냐? 좀 쉬자 ㅠㅠ - 미국 대학원 일상 Vlog
# 15  2022-08-20T20:26:52Z         미국 데이터 사이언스 석사 개강 Vlog - 다사다난 좌충우돌 개강 버텨내기
# 16  2022-08-20T20:26:52Z            개강 준비하는 미국 석사 유학생 Vlog - 왜 하는 거 없이 바쁘지?
# 17  2022-08-20T20:26:52Z            드디어 미국이다!(토하는중) - 미국 석사 유학생 도착 1주일 Vlog
# 18  2022-08-20T20:26:52Z               미국 대학원 출국 1달 전에 뭘 해야 할까? - 출국준비 Vlog
# 19  2022-08-20T20:26:52Z   대기업 직장인 퇴사 Vlog(I quit my job) - 미국 대학원 인생 2막 준비
# 20  2022-08-20T20:26:52Z  대학원 합격 이후 근황 Vlog (Vlog about after_graduation...
# 21  2022-08-20T20:26:52Z  미국 대학원 도전 Vlog(2.5 학점으로 이게되네?) - Vlog of my ch...
#
#             IDS  ListNo
# 0   fLA0abcqyTE       2
# 1   aBtYmx-AhlU       2
# 2   frxWAxQvPcw       2
# 3   5TQPtOVdr9Y       2
# 4   am2TFveOX08       2
# 5   mtPM6m3J0QU       2
# 6   fRLiHCW-HXA       2
# 7   sAVPn9qOdcc       2
# 8   7DaoE5EUDIw       2
# 9   NpXESg1GqRk       2
# 10  VsQeS8z0tfM       2
# 11  Bo5usDu_t_I       2
# 12  6XOlmD5iZes       2
# 13  fyiAufzWod4       2
# 14  8VzxoKJ8Ylg       2
# 15  P3T_il0mG80       2
# 16  V_rbUxwaU7U       2
# 17  peAs1HP1xx4       2
# 18  fAGgtI8LQRw       2
# 19  kkR1kAiScLQ       2
# 20  38gF8dJ9oVw       2
# 21  OEZaq8ABHTM       2

# %%
dtcu3=df['PlayLists'][2]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu3,
    part='snippet',
    maxResults=50)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf3=pd.DataFrame([date,video_names,video_ids]).T
vdf3.columns=['Date','Title','IDS']
vdf3['ListNo'] = 3

# %%
# Appending all lists into one single dataframe and reset the index to aviod index duplication
tdf = vdf.append(vdf2)
tdf = tdf.append(vdf3)
tdf.reset_index(inplace=True, drop=True)
tdf
#tdf['IDS'][0]
# Out:
#                     Date                                              Title  \
# 0   2022-08-20T20:27:40Z                    한국 음식이 너무 그리운(?) 미국 유학생 #shorts
# 1   2022-08-20T20:27:40Z                              미국에서 보내는 첫 생일 #Shorts
# 2   2022-08-20T20:27:40Z                              맛이 가버린 텍사스 날씨 #shorts
# 3   2022-08-20T20:27:40Z                       새해를 맞이하는 게으른 유학생의 자세 #Shorts
# 4   2022-08-20T20:27:40Z       #Shorts Merry Christmas! 미국 유학생이 크리스마스 즐기는 법
# 5   2022-08-20T20:27:40Z    IPhone 13 Pro 예구 - 컴퓨터, 아이패드 다음은 아이폰이에요 #shorts
# 6   2022-08-20T20:27:40Z              이것이 미국의 스케일.. This is America #shorts
# 7   2022-08-20T20:28:50Z                      낮에 영상 20도인데 밤에 눈이 온다? #shorts
# 8   2022-08-20T20:26:52Z                      미국 대학원생 여름학기 일상 Vlog - 벌써 1년?
# 9   2022-08-20T20:26:52Z         미국 인턴 구르는 Vlog - 본격 예비 외노자(되고싶다)의 미국 회사 체험
# 10  2022-08-20T20:26:52Z        여름방학 맞아 푹 삶아진(?) 미국 대학원생 Vlog - 응 몰라 일단 쉴거야
# 8   fLA0abcqyTE       2
# 9   aBtYmx-AhlU       2
# 10  frxWAxQvPcw       2
# 11  5TQPtOVdr9Y       2
# 12  am2TFveOX08       2
# 13  mtPM6m3J0QU       2
# 14  fRLiHCW-HXA       2
# 15  sAVPn9qOdcc       2
# 16  7DaoE5EUDIw       2
# 17  NpXESg1GqRk       2
# 18  VsQeS8z0tfM       2
# 19  Bo5usDu_t_I       2
# 20  6XOlmD5iZes       2
# 21  fyiAufzWod4       2
# 22  8VzxoKJ8Ylg       2
# 23  P3T_il0mG80       2
# 24  V_rbUxwaU7U       2
# 25  peAs1HP1xx4       2
# 26  fAGgtI8LQRw       2
# 27  kkR1kAiScLQ       2
# 28  38gF8dJ9oVw       2
# 29  OEZaq8ABHTM       2
# 30  LS0ORPxc65o       3
# 31  REKVL52Sf0s       3
# 32  2gzEGYYKytg       3

# %%
# Dislike count value has been removed according to Youtube's policy of not exposing the count of dislike.

import re

category_id=[]
views=[]
likes=[]
comments=[]
mins=[]
seconds=[]
title=[]
date=[]

for u in range(len(tdf)):
    request=youtube.videos().list(
    part='snippet,contentDetails,statistics',
    id=tdf['IDS'][u])
    
    response=request.execute()
    
    if response['items']==[]:
        ids.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        comments.append('-')
        date.append('-')
        
    else :
        title.append(response['items'][0]['snippet']['title'])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        date.append(response['items'][0]['snippet']['publishedAt'])
        
dtcu_df=pd.DataFrame([title,category_id,views,likes,comments,date]).T
dtcu_df.columns=['title','category_id','views','likes','comments','date']
dtcu_df['IDS'] = tdf['IDS']
dtcu_df
# Out:
#                                                 title category_id  views  \
# 0                     한국 음식이 너무 그리운(?) 미국 유학생 #shorts          22    659
# 1                               미국에서 보내는 첫 생일 #Shorts          22    388
# 2                               맛이 가버린 텍사스 날씨 #shorts          27    327
# 3                        새해를 맞이하는 게으른 유학생의 자세 #Shorts          27    269
# 4        #Shorts Merry Christmas! 미국 유학생이 크리스마스 즐기는 법          27    317
# 5     IPhone 13 Pro 예구 - 컴퓨터, 아이패드 다음은 아이폰이에요 #shorts          27    434
# 6               이것이 미국의 스케일.. This is America #shorts          27    772
# 7                       낮에 영상 20도인데 밤에 눈이 온다? #shorts          27    179
# 8                       미국 대학원생 여름학기 일상 Vlog - 벌써 1년?          22    504
# 9          미국 인턴 구르는 Vlog - 본격 예비 외노자(되고싶다)의 미국 회사 체험          22   1466
# 10        여름방학 맞아 푹 삶아진(?) 미국 대학원생 Vlog - 응 몰라 일단 쉴거야          22    716
# 11  기말고사까지 우당탕탕 치른 미국 대학원생 Vlog - 이겨내는 것이 아니라 버티는 것이다          22    586
# 13    26       20  2022-01-20T08:34:16Z  mtPM6m3J0QU
# 14    47       27  2022-01-01T09:33:14Z  fRLiHCW-HXA
# 15    34       23  2021-12-25T04:58:33Z  sAVPn9qOdcc
# 16    40       25  2021-12-16T10:00:07Z  7DaoE5EUDIw
# 17    36       21  2021-11-23T09:27:13Z  NpXESg1GqRk
# 18    29       16  2021-11-06T11:00:13Z  VsQeS8z0tfM
# 19    52       34  2021-10-11T09:00:10Z  Bo5usDu_t_I
# 20    34       24  2021-09-25T09:15:00Z  6XOlmD5iZes
# 21    63       26  2021-09-11T13:12:33Z  fyiAufzWod4
# 22    43       22  2021-09-06T09:15:00Z  8VzxoKJ8Ylg
# 23    73       35  2021-08-29T11:00:07Z  P3T_il0mG80
# 24    57       46  2021-08-17T09:15:01Z  V_rbUxwaU7U
# 25    75       46  2021-08-10T09:15:01Z  peAs1HP1xx4
# 26    52       35  2021-07-21T05:47:43Z  fAGgtI8LQRw
# 27    55       39  2021-06-27T03:25:04Z  kkR1kAiScLQ
# 28    68       19  2021-06-20T04:19:46Z  38gF8dJ9oVw
# 29   381      112  2021-04-18T14:46:23Z  OEZaq8ABHTM
# 30    49       30  2022-07-06T11:00:11Z  LS0ORPxc65o
# 31   134       59  2021-07-10T23:00:05Z  REKVL52Sf0s
# 32    73       32  2021-10-04T09:15:01Z  2gzEGYYKytg

# %%
# Sorted lists merging - validation checked
dtcu_df['cat_clean'] = 0
for i in range(len(tdf)):
    if tdf['Title'][i] == dtcu_df['title'][i]:
        dtcu_df['cat_clean'][i] = tdf['ListNo'][i]
dtcu_df
# Out:
#                                                 title category_id  views  \
# 0                     한국 음식이 너무 그리운(?) 미국 유학생 #shorts          22    659
# 1                               미국에서 보내는 첫 생일 #Shorts          22    388
# 2                               맛이 가버린 텍사스 날씨 #shorts          27    327
# 3                        새해를 맞이하는 게으른 유학생의 자세 #Shorts          27    269
# 4        #Shorts Merry Christmas! 미국 유학생이 크리스마스 즐기는 법          27    317
# 5     IPhone 13 Pro 예구 - 컴퓨터, 아이패드 다음은 아이폰이에요 #shorts          27    434
# 6               이것이 미국의 스케일.. This is America #shorts          27    772
# 7                       낮에 영상 20도인데 밤에 눈이 온다? #shorts          27    179
# 8                       미국 대학원생 여름학기 일상 Vlog - 벌써 1년?          22    504
# 9          미국 인턴 구르는 Vlog - 본격 예비 외노자(되고싶다)의 미국 회사 체험          22   1466
# 10        여름방학 맞아 푹 삶아진(?) 미국 대학원생 Vlog - 응 몰라 일단 쉴거야          22    716
# 11  기말고사까지 우당탕탕 치른 미국 대학원생 Vlog - 이겨내는 것이 아니라 버티는 것이다          22    586
# 12          또 첫 학기 어찌저찌 보낸 미국 대학원생 Vlog - 달라지기 위한 나날들          27    990
# 13      미국 대학원생 방학에 좀 숨 돌리는 Vlog - 아니 왜 벌써 개강인데.....?          27    555
# 15    34       23  2021-12-25T04:58:33Z  sAVPn9qOdcc          2
# 16    40       25  2021-12-16T10:00:07Z  7DaoE5EUDIw          2
# 17    36       21  2021-11-23T09:27:13Z  NpXESg1GqRk          2
# 18    29       16  2021-11-06T11:00:13Z  VsQeS8z0tfM          2
# 19    52       34  2021-10-11T09:00:10Z  Bo5usDu_t_I          2
# 20    34       24  2021-09-25T09:15:00Z  6XOlmD5iZes          2
# 21    63       26  2021-09-11T13:12:33Z  fyiAufzWod4          2
# 22    43       22  2021-09-06T09:15:00Z  8VzxoKJ8Ylg          2
# 23    73       35  2021-08-29T11:00:07Z  P3T_il0mG80          2
# 24    57       46  2021-08-17T09:15:01Z  V_rbUxwaU7U          2
# 25    75       46  2021-08-10T09:15:01Z  peAs1HP1xx4          2
# 26    52       35  2021-07-21T05:47:43Z  fAGgtI8LQRw          2
# 27    55       39  2021-06-27T03:25:04Z  kkR1kAiScLQ          2
# 28    68       19  2021-06-20T04:19:46Z  38gF8dJ9oVw          2
# 29   381      112  2021-04-18T14:46:23Z  OEZaq8ABHTM          2
# 30    49       30  2022-07-06T11:00:11Z  LS0ORPxc65o          3
# 31   134       59  2021-07-10T23:00:05Z  REKVL52Sf0s          3
# 32    73       32  2021-10-04T09:15:01Z  2gzEGYYKytg          3

# %% [markdown]
# ## Data Glancing

# %%
# Labeling
# Cat1 = Shorts
# Cat2 = Daily Vlog
# Cat3 = Q&A, Infos

cal_1 = dtcu_df[dtcu_df['cat_clean'] == 1]
cal_2 = dtcu_df[dtcu_df['cat_clean'] == 2]
cal_3 = dtcu_df[dtcu_df['cat_clean'] == 3]

comp1 = pd.to_numeric(cal_1[['category_id', 'views']].views).mean()
comp2 = pd.to_numeric(cal_2[['category_id', 'views']].views).mean()
comp3 = pd.to_numeric(cal_3[['category_id', 'views']].views).mean()
compf = [round(comp1, 2), round(comp2, 2), round(comp3, 2)]
compf

plt.figure(figsize=(5, 7))
x = np.arange(3)
cat_label = ['Shorts', 'Daily Vlog', 'Q&A, Infos']

plt.bar(x, compf)
plt.xticks(x, cat_label)

for i, v in enumerate(x):
    plt.text(v, compf[i], str(compf[i]),
             fontsize=12,
             color="red",
             horizontalalignment='center',
             verticalalignment='bottom')

plt.title('Average Views of video clips / Categories', fontsize=20)
plt.show()

# %%
from datetime import datetime, date

dtcu_df['weekday'] = 0
dateDict = {0: 'Mon', 1: 'Tue', 2: 'Wed', 3: 'Thu', 4: 'Fri', 5: 'Sat', 6: 'Sun'}

for i in range(len(dtcu_df)):
    dtcu_df['date'][i] = (dtcu_df['date'][i][:10])
    dtcu_df['date'][i] = datetime.strptime(dtcu_df['date'][i], '%Y-%m-%d')
    dtcu_df['weekday'][i] = dtcu_df['date'][i].weekday()
    dtcu_df['weekday'][i] = dateDict[dtcu_df['weekday'][i]]

# %%
dtcu_df.head(10)
# Out:
#                                              title category_id views likes  \
# 0                  한국 음식이 너무 그리운(?) 미국 유학생 #shorts          22   659    15
# 1                            미국에서 보내는 첫 생일 #Shorts          22   388    32
# 2                            맛이 가버린 텍사스 날씨 #shorts          27   327    14
# 3                     새해를 맞이하는 게으른 유학생의 자세 #Shorts          27   269    11
# 4     #Shorts Merry Christmas! 미국 유학생이 크리스마스 즐기는 법          27   317    15
# 5  IPhone 13 Pro 예구 - 컴퓨터, 아이패드 다음은 아이폰이에요 #shorts          27   434    19
# 6            이것이 미국의 스케일.. This is America #shorts          27   772    18
# 7                    낮에 영상 20도인데 밤에 눈이 온다? #shorts          27   179     6
# 8                    미국 대학원생 여름학기 일상 Vlog - 벌써 1년?          22   504    52
# 9       미국 인턴 구르는 Vlog - 본격 예비 외노자(되고싶다)의 미국 회사 체험          22  1466    46
#
#   comments                 date          IDS  cat_clean weekday
# 0       13  2022-08-10 00:00:00  EQ4xjclxig0          1     Wed
# 1       14  2022-06-08 00:00:00  AA2ls2fBwdU          1     Wed
# 2        2  2022-04-05 00:00:00  o12WipNjpwM          1     Tue
# 3        6  2022-01-08 00:00:00  RqM5xtkC5HM          1     Sat
# 4        3  2021-12-25 00:00:00  uTeI3PZPAD0          1     Sat
# 5       12  2021-09-18 00:00:00  Kfzax_mz-lA          1     Sat
# 6       12  2021-08-11 00:00:00  yXLNw6gebsA          1     Wed
# 7        4  2022-02-04 00:00:00  7mzOuRN1zq0          1     Fri
# 8       28  2022-07-31 00:00:00  fLA0abcqyTE          2     Sun
# 9       38  2022-06-18 00:00:00  aBtYmx-AhlU          2     Sat

# %% [markdown]
# ## Extraction Reply

# %%
youtube = build(api_service_name, api_ver, developerKey = dev_key)

reviews = []

for i in range(len(dtcu_df)):
    cm = youtube.commentThreads().list(
        videoId = dtcu_df['IDS'][i],
        order = 'relevance',
        part = 'snippet',
        maxResults = 100
    ).execute()
    for i in cm['items']:
        reviews.append(i['snippet']['topLevelComment']['snippet']['textOriginal'])

adf = pd.DataFrame(reviews, columns=['Comments'])
adf
# Out:
#                                               Comments
# 0    요즘은 정말 한식이 많아져서~사실 맛있는곳도 많아서 유학생활 할때 참 도움이 많이 ...
# 1    영상 항상 잘 보고있습니다 :) 이번 영상은 bgm이 너무 좋아서 찾아봤네요ㅎㅎ 덕...
# 2                              화이팅입니다 항상 챙겨보면서 응원하고있어요
# 3                                            달라스 클라쓰 🤭
# 4                                      사실 한국 어딘가에 있었다는
# ..                                                 ...
# 414                                         형님 감사합니다!!
# 415  와 정말 적게 쓰시네요!! 대학원생활하면서 살림이 가능하신가용?? 저는 맨날 사먹거...
# 416                혹시 박사생이시면 텍사스 지역 스트라이펜드 얼마정도 받으세요??
# 417               스타벅스는 정말 국룰이군요..ㅋㅋㅋㅋㅋ 커피만은 포기못해.....
# 418                                    자막 넣으면 좀더 좋을듯 ㅎ
#
# [419 rows x 1 columns]
