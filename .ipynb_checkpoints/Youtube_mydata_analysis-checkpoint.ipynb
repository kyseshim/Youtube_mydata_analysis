# %%
#!pip install --upgrade google-api-python-client
#!pip install oauth2client

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

import matplotlib.pyplot as plt
import apikey

# %%
dev_key = apikey.api_key
api_service_name = "youtube"
api_ver = "v3"

# %%
youtube = build(api_service_name, api_ver, developerKey = dev_key)

# %%
search_response = youtube.search().list(
    q = "공부하는섭이",
    order = "relevance",
    part = "snippet",
    maxResults = 50
    ).execute()

# %%
channel_id = search_response['items'][0]['id']['channelId']

# %%
playlists = youtube.playlists().list(
    channelId = channel_id,
    part = "snippet",
    maxResults = 20
    ).execute()

# %%
import pandas as pd

ids=[]
titles=[]
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])
    
df=pd.DataFrame([ids,titles]).T
df.columns=['PlayLists','Titles']

df.head(5)
# Out:
#                             PlayLists       Titles
# 0  PLfkfgvn_kFAU6nfQ-zL_JV8D_SWeHVuRV       Shorts
# 1  PLfkfgvn_kFAX8jvsuRcoFp6CFPAUehok8      일상 Vlog
# 2  PLfkfgvn_kFAV4YksRjqGU_H9dWmMRylSG  Q&A / 정보 제공

# %%
#Videos' list
dtcu=df['PlayLists'][0]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu,
    part='snippet',
    maxResults=50)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf=pd.DataFrame([date,video_names,video_ids]).T
vdf.columns=['Date','Title','IDS']
#vdf

# %%
dtcu2=df['PlayLists'][1]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu2,
    part='snippet',
    maxResults=50)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf2=pd.DataFrame([date,video_names,video_ids]).T
vdf2.columns=['Date','Title','IDS']
#vdf2

# %%
dtcu3=df['PlayLists'][2]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu3,
    part='snippet',
    maxResults=50)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf3=pd.DataFrame([date,video_names,video_ids]).T
vdf3.columns=['Date','Title','IDS']
#vdf3

# %%
# Appending all lists into one single dataframe and reset the index to aviod index duplication
tdf = vdf.append(vdf2)
tdf = tdf.append(vdf3)
tdf.reset_index(inplace=True, drop=True)
#tdf

# %%
# Dislike count value has been removed according to Youtube's policy of not exposing the count of dislike.

import re

category_id=[]
views=[]
likes=[]
comments=[]
mins=[]
seconds=[]
title=[]
date=[]

for u in range(len(tdf)):
    request=youtube.videos().list(
    part='snippet,contentDetails,statistics',
    id=tdf['IDS'][u])
    
    response=request.execute()
    
    if response['items']==[]:
        ids.append('-')
        category_id.append('-')
        views.append('-')
        likes.append('-')
        comments.append('-')
        date.append('-')
        
    else :
        title.append(response['items'][0]['snippet']['title'])
        category_id.append(response['items'][0]['snippet']['categoryId'])
        views.append(response['items'][0]['statistics']['viewCount'])
        likes.append(response['items'][0]['statistics']['likeCount'])
        comments.append(response['items'][0]['statistics']['commentCount'])
        date.append(response['items'][0]['snippet']['publishedAt'])
        
dtcu_df=pd.DataFrame([title,category_id,views,likes,comments,date]).T
dtcu_df.columns=['title','category_id','views','likes','comments','date']
dtcu_df
# Out:
#                                                 title category_id  views  \
# 0                     한국 음식이 너무 그리운(?) 미국 유학생 #shorts          22    616
# 1                               미국에서 보내는 첫 생일 #Shorts          22    385
# 2                               맛이 가버린 텍사스 날씨 #shorts          27    326
# 3                        새해를 맞이하는 게으른 유학생의 자세 #Shorts          27    269
# 4        #Shorts Merry Christmas! 미국 유학생이 크리스마스 즐기는 법          27    317
# 5     IPhone 13 Pro 예구 - 컴퓨터, 아이패드 다음은 아이폰이에요 #shorts          27    433
# 6               이것이 미국의 스케일.. This is America #shorts          27    768
# 7                       낮에 영상 20도인데 밤에 눈이 온다? #shorts          27    179
# 8                       미국 대학원생 여름학기 일상 Vlog - 벌써 1년?          22    482
# 9          미국 인턴 구르는 Vlog - 본격 예비 외노자(되고싶다)의 미국 회사 체험          22   1449
# 10        여름방학 맞아 푹 삶아진(?) 미국 대학원생 Vlog - 응 몰라 일단 쉴거야          22    715
# 11  기말고사까지 우당탕탕 치른 미국 대학원생 Vlog - 이겨내는 것이 아니라 버티는 것이다          22    585
# ...

# %%
#dtcu_df['title', 'views'].groupby(['title'], as_index=True).mean().plot.bar()
#dtcu_df[['title', 'views']].plot.bar()
xis = dtcu_df['title']
yis = dtcu_df['views']

x = np.arange(33)

plt.figure(figsize=(20,30))

plt.bar(x, yis, color='y')
# plt.bar(x, values, color='dodgerblue')
# plt.bar(x, values, color='C2')
# plt.bar(x, values, color='#e35f62')
plt.xticks(x, xis)

plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49885 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#dtcu_df[['category_id', 'views']].groupby(['category_id'], as_index=True).mean().plot.bar()
cal_22 = dtcu_df[dtcu_df['category_id'] == '22']
#dtcu_df[['category_id', 'views']].views
cal_27 = dtcu_df[dtcu_df['category_id'] == '27']

comp1 = pd.to_numeric(cal_27[['category_id', 'views']].views).mean()
comp2 = pd.to_numeric(cal_22[['category_id', 'views']].views).mean()
compf = [comp1, comp2]
compf
# Out:
# [1216.08, 2427.125]
